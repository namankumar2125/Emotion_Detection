# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <!-- TODO(b/319266067) remove temporary advert after a few weeks. -->
# <div class="markdown-google-sans">
#   <h2>(New) Try the Gemini API</h2>
#   <ul>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Talk_to_Gemini_with_Google%27s_Speech_to_Text_API.ipynb?utm_medium=link&utm_campaign=gemini">Talk to Gemini with the Speech-to-Text API</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Learning_with_Gemini_and_ChatGPT.ipynb?utm_medium=link&utm_campaign=gemini">Compare Gemini with ChatGPT</a></li>
#   <li><a href="https://colab.google/notebooks/?utm_medium=link&utm_campaign=gemini">More notebooks</a></li>
#   </ul>
# </div>

# %% [markdown]
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view, and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing 3 cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [NeMo Voice Swap](https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb): Use Nvidia's NeMo conversational AI Toolkit to swap a voice in an audio fragment with a computer generated one.
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (AMD EPYC 7B12)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/107.7 GB disk)

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd {HOME}
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/My Drive/Colab Notebooks'
# !ls
# Access the video file
SOURCE_VIDEO_PATH = '/content/drive/MyDrive/Colab Notebooks/InputVideo 1.mp4'
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks
#  best2.pt   'Copy of Welcome To Colaboratory'   Untitled0.ipynb   Untitled2.ipynb
#  ByteTrack  'InputVideo 1.mp4'		        Untitled1.ipynb

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112 and https://github.com/roboflow/notebooks/issues/106
# !pip install -q loguru lap thop

from IPython import display
display.clear_output()


import sys
sys.path.append(f"{HOME}/ByteTrack")


import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %%
# !pip install supervision==0.1.0


from IPython import display
display.clear_output()


import supervision
print("supervision.__version__:", supervision.__version__)
# Out:
# supervision.__version__: 0.1.0

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %%
# settings
MODEL = '/content/drive/MyDrive/Colab Notebooks/best2.pt'

# %%
from ultralytics import YOLO

model = YOLO(MODEL)
model.fuse()
# Out:
# Model summary (fused): 268 layers, 68129346 parameters, 0 gradients, 257.4 GFLOPs

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [0, 1, 2, 3, 4, 5]

# %%
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create instance of BoxAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=2, text_thickness=2, text_scale=1)

# acquire first video frame
iterator = iter(generator)
frame = next(iterator)
# model prediction on single frame and conversion to supervision Detections
results = model(frame)
detections = Detections(
    xyxy=results[0].boxes.xyxy.cpu().numpy(),
    confidence=results[0].boxes.conf.cpu().numpy(),
    class_id=results[0].boxes.cls.cpu().numpy().astype(int)
)
# format custom labels
labels = [
    f"{CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
    for _, confidence, class_id, tracker_id
    in detections
]
# annotate and display frame
frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)

# %matplotlib inline
show_frame_in_notebook(frame, (16, 16))
# Out:
# 0: 384x640 1 Bus, 29 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2374.9ms
# Speed: 27.7ms preprocess, 2374.9ms inference, 28.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
# settings
LINE_START_1 = Point(808, 1142)
LINE_END_1 = Point(1172, 2070)

LINE_START_2 = Point(3360, 654)
LINE_END_2 = Point(3092, 142)

LINE_START_3 = Point(2196, 10)
LINE_END_3 = Point(1364, 182)

LINE_START_4 = Point(1508, 2154)
LINE_END_4 = Point(2364, 2074)

# %%
TARGET_VIDEO_PATH = '/content/result.mp4'

# %%
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# Out:
# VideoInfo(width=3840, height=2160, fps=29, total_frames=261)

# %%
# !pip install opencv-python
import cv2
import numpy as np
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)

# %%
from tqdm.notebook import tqdm
import time
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Initialize a dictionary to store object trajectories (lines)
object_trajectories = {}
# Create a variable to store the previous frame's timestamp
prev_timestamp = None
# Frame rate of the video (you may need to adjust this value)
frame_rate = 29.97  # Adjusted frame rate to match the video's frame rate
# Conversion factor from pixels to meters
pixels_to_meters = 0.12  # 1 pixel ≈ 0.054 meters
# Conversion factor from meters per second to kilometers per hour
mps_to_kmph = 3.6
# Define the moving average window size
speed_window_size = 30  # Adjust this value as needed
# Initialize an empty dictionary to store previous speed values
speed_history = {}
# Smoothing parameters
smoothing_window_size = 10  # Adjust this value for desired smoothing

# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
line_counter_1 = LineCounter(start=LINE_START_1, end=LINE_END_1)
line_counter_2 = LineCounter(start=LINE_START_2, end=LINE_END_2)
line_counter_3 = LineCounter(start=LINE_START_3, end=LINE_END_3)
line_counter_4 = LineCounter(start=LINE_START_4, end=LINE_END_4)
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette(), thickness=2, text_thickness=2, text_scale=1)
line_annotator = LineCounterAnnotator(thickness=2, text_thickness=2, text_scale=1)

# open target video file
with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    for frame in tqdm(generator, total=video_info.total_frames):
        current_timestamp = time.time()
        if prev_timestamp is not None:
            time_elapsed = current_timestamp - prev_timestamp
        else:
            time_elapsed = 0.0
        prev_timestamp = current_timestamp

        # model prediction on a single frame and conversion to supervision Detections
        results = model(frame)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)

        # Calculate and update the speed information for each tracked object
        for track in tracks:
            if track.track_id in object_trajectories:
                centroid_trajectory = object_trajectories[track.track_id]
                x_center = int((track.tlbr[0] + track.tlbr[2]) / 2)
                y_center = int((track.tlbr[1] + track.tlbr[3]) / 2)
                centroid_trajectory.append((x_center, y_center))
                object_trajectories[track.track_id] = centroid_trajectory
                # Calculate the distance between consecutive centroids in pixels
                if len(centroid_trajectory) >= 2:
                    prev_x, prev_y = centroid_trajectory[-2]
                    curr_x, curr_y = centroid_trajectory[-1]
                    distance_pixels = np.sqrt((curr_x - prev_x) ** 2 + (curr_y - prev_y) ** 2)
                    # Calculate speed in m/s and then convert to km/h
                    speed_mps = distance_pixels * pixels_to_meters / time_elapsed
                    speed_kmph = int(round(speed_mps * mps_to_kmph))
                else:
                    speed_kmph = 0

            else:
                speed_kmph = 0

            # Append the current speed to the speed history dictionary
            if track.track_id not in speed_history:
                speed_history[track.track_id] = []
            speed_history[track.track_id].append(speed_kmph)

        # Apply smoothing to speed values
        for track_id, speeds in speed_history.items():
            if len(speeds) >= smoothing_window_size:
                smoothed_speeds = np.convolve(speeds, np.ones(smoothing_window_size)/smoothing_window_size, mode='valid')
                speed_history[track_id] = smoothed_speeds.tolist()  # Convert back to a Python list

        # Format custom labels with speed information
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f} {speed_history[tracker_id][-1]:.2f}km/h"
            for _, confidence, class_id, tracker_id
            in detections
        ]

        # Draw trace lines for tracked objects
        for track in tracks:
            if track.track_id in object_trajectories:
                # Retrieve the centroid trajectory of the object
                centroid_trajectory = object_trajectories[track.track_id]
                # Draw lines connecting the object's previous centroid positions
                for i in range(1, len(centroid_trajectory)):
                    cv2.line(frame, centroid_trajectory[i - 1], centroid_trajectory[i], (0, 255, 0), 2)
            else:
                # If the object is not in the dictionary, create a new trajectory
                centroid_trajectory = []

            # Calculate the centroid of the bounding box
            x_center = int((track.tlbr[0] + track.tlbr[2]) / 2)
            y_center = int((track.tlbr[1] + track.tlbr[3]) / 2)

            # Update the object's trajectory with the current position
            centroid_trajectory.append((x_center, y_center))
            object_trajectories[track.track_id] = centroid_trajectory

        # updating line counter
        line_counter_1.update(detections=detections)
        line_counter_2.update(detections=detections)
        line_counter_3.update(detections=detections)
        line_counter_4.update(detections=detections)

        # Count the total number of objects detected and tracked
        total_objects_detected = len(detections)

        # Count the classified objects by class
        class_counters = {class_id: np.sum(detections.class_id == class_id) for class_id in CLASS_ID}

        # Create text to display counts on the frame
        count_text = f"\nTotal: {total_objects_detected}\n"
        count_text += "\n".join([f"{CLASS_NAMES_DICT[class_id]}: {count}" for class_id, count in class_counters.items()])

        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        line_annotator.annotate(frame=frame, line_counter=line_counter_1)
        line_annotator.annotate(frame=frame, line_counter=line_counter_2)
        line_annotator.annotate(frame=frame, line_counter=line_counter_3)
        line_annotator.annotate(frame=frame, line_counter=line_counter_4)

        # Add the count text to the frame
        for i, line in enumerate(count_text.split('\n')):
            cv2.putText(frame, line, (10, 10 + i * 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        # Write the frame to the output video
        sink.write_frame(frame)

# Video processing completed
print("Video processing completed.")

# Plot the speed variation profile of tracked vehicles
plt.figure(figsize=(12, 6))

for track_id, speeds in speed_history.items():
    plt.plot(range(len(speeds)), speeds, label=f'Tracked Object {track_id}')

plt.xlabel('Frame Number')
plt.ylabel('Speed (km/h)')
plt.title('Speed Variation Profile of Tracked Vehicles')
plt.legend()
plt.show()
# Out:
#   0%|          | 0/261 [00:00<?, ?it/s]
# 0: 384x640 1 Bus, 29 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1977.5ms
# Speed: 3.5ms preprocess, 1977.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 30 Cars, 7 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1970.3ms
# Speed: 2.3ms preprocess, 1970.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 7 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1902.0ms
# Speed: 2.3ms preprocess, 1902.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 29 Cars, 6 Motorcycles, 1 Tractor-trolley, 4 Trucks, 3946.3ms
# Speed: 2.2ms preprocess, 3946.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 30 Cars, 6 Motorcycles, 1 Tractor-trolley, 4 Trucks, 3565.2ms
# Speed: 2.1ms preprocess, 3565.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 6 Motorcycles, 1 Tractor-trolley, 5 Trucks, 3071.8ms
# Speed: 1.9ms preprocess, 3071.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 29 Cars, 5 Motorcycles, 1 Tractor-trolley, 5 Trucks, 3058.4ms
# Speed: 2.5ms preprocess, 3058.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 30 Cars, 5 Motorcycles, 1 Tractor-trolley, 6 Trucks, 3864.0ms
# Speed: 2.1ms preprocess, 3864.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 29 Cars, 6 Motorcycles, 1 Tractor-trolley, 2 Trucks, 1869.8ms
# Speed: 2.4ms preprocess, 1869.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 7 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1866.4ms
# Speed: 2.4ms preprocess, 1866.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 29 Cars, 7 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1873.5ms
# Speed: 2.0ms preprocess, 1873.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 30 Cars, 6 Motorcycles, 1 Tractor-trolley, 2 Trucks, 1874.3ms
# Speed: 2.1ms preprocess, 1874.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 7 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2328.2ms
# Speed: 2.4ms preprocess, 2328.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 7 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1859.2ms
# Speed: 2.5ms preprocess, 1859.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 4 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1889.8ms
# Speed: 2.1ms preprocess, 1889.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 5 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1878.6ms
# Speed: 4.5ms preprocess, 1878.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 6 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1864.4ms
# Speed: 2.2ms preprocess, 1864.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1884.0ms
# Speed: 2.3ms preprocess, 1884.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 30 Cars, 9 Motorcycles, 1 Tractor-trolley, 3 Trucks, 2356.0ms
# Speed: 2.7ms preprocess, 2356.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 30 Cars, 8 Motorcycles, 1 Tractor-trolley, 2 Trucks, 1859.7ms
# Speed: 2.2ms preprocess, 1859.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1871.0ms
# Speed: 2.3ms preprocess, 1871.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 6 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1864.3ms
# Speed: 2.4ms preprocess, 1864.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 7 Motorcycles, 2 Tractor-trolleys, 4 Trucks, 1869.6ms
# Speed: 2.2ms preprocess, 1869.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 7 Motorcycles, 2 Tractor-trolleys, 4 Trucks, 1867.4ms
# Speed: 2.1ms preprocess, 1867.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 6 Motorcycles, 2 Tractor-trolleys, 3 Trucks, 2284.8ms
# Speed: 2.1ms preprocess, 2284.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 5 Motorcycles, 2 Tractor-trolleys, 6 Trucks, 1890.6ms
# Speed: 2.4ms preprocess, 1890.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 26 Cars, 6 Motorcycles, 2 Tractor-trolleys, 4 Trucks, 1874.2ms
# Speed: 2.0ms preprocess, 1874.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1872.9ms
# Speed: 2.4ms preprocess, 1872.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 8 Motorcycles, 2 Tractor-trolleys, 5 Trucks, 1856.8ms
# Speed: 2.1ms preprocess, 1856.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 8 Motorcycles, 2 Tractor-trolleys, 4 Trucks, 1945.4ms
# Speed: 2.0ms preprocess, 1945.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 11 Motorcycles, 2 Tractor-trolleys, 4 Trucks, 2223.9ms
# Speed: 2.1ms preprocess, 2223.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 11 Motorcycles, 2 Tractor-trolleys, 2 Trucks, 1867.8ms
# Speed: 2.1ms preprocess, 1867.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 24 Cars, 9 Motorcycles, 2 Tractor-trolleys, 5 Trucks, 1888.3ms
# Speed: 2.1ms preprocess, 1888.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 24 Cars, 8 Motorcycles, 2 Tractor-trolleys, 8 Trucks, 1878.0ms
# Speed: 3.2ms preprocess, 1878.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 8 Motorcycles, 2 Tractor-trolleys, 6 Trucks, 1863.6ms
# Speed: 2.2ms preprocess, 1863.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 6 Motorcycles, 2 Tractor-trolleys, 5 Trucks, 1904.5ms
# Speed: 2.5ms preprocess, 1904.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 30 Cars, 6 Motorcycles, 1 Tractor-trolley, 2 Trucks, 2200.9ms
# Speed: 2.2ms preprocess, 2200.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 29 Cars, 8 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1873.8ms
# Speed: 2.0ms preprocess, 1873.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 8 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1871.1ms
# Speed: 2.6ms preprocess, 1871.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 29 Cars, 7 Motorcycles, 2 Tractor-trolleys, 7 Trucks, 1860.3ms
# Speed: 2.4ms preprocess, 1860.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 9 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1892.4ms
# Speed: 2.1ms preprocess, 1892.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 8 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1983.5ms
# Speed: 2.2ms preprocess, 1983.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 10 Motorcycles, 2 Tractor-trolleys, 7 Trucks, 2232.6ms
# Speed: 2.2ms preprocess, 2232.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 12 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1885.5ms
# Speed: 2.7ms preprocess, 1885.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 8 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1863.2ms
# Speed: 3.0ms preprocess, 1863.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1892.7ms
# Speed: 1.9ms preprocess, 1892.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 29 Cars, 10 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1869.5ms
# Speed: 2.1ms preprocess, 1869.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 11 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2060.7ms
# Speed: 2.1ms preprocess, 2060.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Buss, 31 Cars, 8 Motorcycles, 1 Tractor-trolley, 3 Trucks, 2092.4ms
# Speed: 2.4ms preprocess, 2092.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 31 Cars, 9 Motorcycles, 1 Tractor-trolley, 2 Trucks, 1892.0ms
# Speed: 2.5ms preprocess, 1892.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 10 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1865.3ms
# Speed: 2.2ms preprocess, 1865.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 29 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1882.1ms
# Speed: 2.0ms preprocess, 1882.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 11 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1862.0ms
# Speed: 2.5ms preprocess, 1862.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 29 Cars, 10 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2113.9ms
# Speed: 2.7ms preprocess, 2113.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 10 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2261.2ms
# Speed: 2.1ms preprocess, 2261.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1877.9ms
# Speed: 2.1ms preprocess, 1877.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 7 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2078.8ms
# Speed: 2.1ms preprocess, 2078.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 29 Cars, 8 Motorcycles, 1 Tractor-trolley, 5 Trucks, 2105.6ms
# Speed: 2.1ms preprocess, 2105.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 8 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1865.9ms
# Speed: 2.9ms preprocess, 1865.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 6 Motorcycles, 1 Tractor-trolley, 7 Trucks, 3261.0ms
# Speed: 1.9ms preprocess, 3261.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 28 Cars, 8 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1874.0ms
# Speed: 2.5ms preprocess, 1874.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 26 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1866.0ms
# Speed: 2.4ms preprocess, 1866.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1893.8ms
# Speed: 2.6ms preprocess, 1893.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1868.0ms
# Speed: 3.7ms preprocess, 1868.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 29 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 2106.4ms
# Speed: 2.2ms preprocess, 2106.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 30 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2054.9ms
# Speed: 2.0ms preprocess, 2054.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 29 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1864.1ms
# Speed: 2.3ms preprocess, 1864.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 29 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1859.1ms
# Speed: 2.1ms preprocess, 1859.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 Cars, 10 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1882.4ms
# Speed: 2.1ms preprocess, 1882.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 Cars, 11 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1862.9ms
# Speed: 2.1ms preprocess, 1862.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 2134.7ms
# Speed: 2.5ms preprocess, 2134.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2045.0ms
# Speed: 2.1ms preprocess, 2045.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 26 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1888.1ms
# Speed: 2.0ms preprocess, 1888.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 27 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1876.3ms
# Speed: 2.3ms preprocess, 1876.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 25 Cars, 10 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1856.9ms
# Speed: 2.9ms preprocess, 1856.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 27 Cars, 11 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1869.2ms
# Speed: 2.0ms preprocess, 1869.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 28 Cars, 11 Motorcycles, 1 Tractor-trolley, 5 Trucks, 2255.2ms
# Speed: 2.9ms preprocess, 2255.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 11 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1939.7ms
# Speed: 2.0ms preprocess, 1939.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 26 Cars, 11 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1865.2ms
# Speed: 2.1ms preprocess, 1865.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 25 Cars, 10 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1861.2ms
# Speed: 2.1ms preprocess, 1861.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 26 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1881.1ms
# Speed: 2.1ms preprocess, 1881.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1867.2ms
# Speed: 4.7ms preprocess, 1867.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 9 Motorcycles, 6 Trucks, 2262.8ms
# Speed: 2.2ms preprocess, 2262.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 10 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1878.0ms
# Speed: 2.2ms preprocess, 1878.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1894.5ms
# Speed: 2.2ms preprocess, 1894.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1883.8ms
# Speed: 2.3ms preprocess, 1883.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1876.4ms
# Speed: 2.2ms preprocess, 1876.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 26 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2021.2ms
# Speed: 2.9ms preprocess, 2021.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 26 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2268.8ms
# Speed: 4.0ms preprocess, 2268.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 9 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1907.7ms
# Speed: 2.1ms preprocess, 1907.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 8 Motorcycles, 1 Tractor-trolley, 2 Trucks, 1864.5ms
# Speed: 2.4ms preprocess, 1864.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 7 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1874.5ms
# Speed: 2.1ms preprocess, 1874.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 27 Cars, 8 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1900.0ms
# Speed: 2.4ms preprocess, 1900.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 10 Motorcycles, 1 Tractor-trolley, 2 Trucks, 1960.5ms
# Speed: 2.4ms preprocess, 1960.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 2 Trucks, 2199.1ms
# Speed: 2.3ms preprocess, 2199.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 1 Bus, 28 Cars, 9 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1921.6ms
# Speed: 2.3ms preprocess, 1921.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 8 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1863.4ms
# Speed: 2.4ms preprocess, 1863.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 8 Motorcycles, 1 Tractor-trolley, 2 Trucks, 1859.9ms
# Speed: 2.2ms preprocess, 1859.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 7 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1898.2ms
# Speed: 2.7ms preprocess, 1898.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 29 Cars, 7 Motorcycles, 1 Tractor-trolley, 3 Trucks, 2045.9ms
# Speed: 2.5ms preprocess, 2045.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 7 Motorcycles, 1 Tractor-trolley, 3 Trucks, 2148.9ms
# Speed: 2.2ms preprocess, 2148.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 7 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1912.4ms
# Speed: 4.3ms preprocess, 1912.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 8 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1878.0ms
# Speed: 2.2ms preprocess, 1878.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1881.6ms
# Speed: 2.8ms preprocess, 1881.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 10 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1891.7ms
# Speed: 2.3ms preprocess, 1891.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 9 Motorcycles, 2 Tractor-trolleys, 3 Trucks, 2084.7ms
# Speed: 2.3ms preprocess, 2084.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 10 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2070.7ms
# Speed: 2.3ms preprocess, 2070.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 28 Cars, 10 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1903.1ms
# Speed: 2.6ms preprocess, 1903.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 12 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1859.5ms
# Speed: 2.2ms preprocess, 1859.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 11 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1840.1ms
# Speed: 2.0ms preprocess, 1840.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 11 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1864.4ms
# Speed: 2.1ms preprocess, 1864.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 9 Motorcycles, 1 Tractor-trolley, 3 Trucks, 2107.3ms
# Speed: 2.2ms preprocess, 2107.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 9 Motorcycles, 2 Tractor-trolleys, 4 Trucks, 2025.9ms
# Speed: 5.9ms preprocess, 2025.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1905.1ms
# Speed: 2.6ms preprocess, 1905.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 25 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1903.0ms
# Speed: 2.2ms preprocess, 1903.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 8 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1880.9ms
# Speed: 2.3ms preprocess, 1880.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1860.5ms
# Speed: 2.5ms preprocess, 1860.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 27 Cars, 8 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2224.7ms
# Speed: 2.1ms preprocess, 2224.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 8 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1965.6ms
# Speed: 3.7ms preprocess, 1965.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 24 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1896.3ms
# Speed: 3.5ms preprocess, 1896.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 25 Cars, 8 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1870.2ms
# Speed: 7.6ms preprocess, 1870.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 24 Cars, 10 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1871.5ms
# Speed: 2.3ms preprocess, 1871.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 24 Cars, 12 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1880.6ms
# Speed: 2.2ms preprocess, 1880.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2270.9ms
# Speed: 3.2ms preprocess, 2270.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 25 Cars, 10 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1875.0ms
# Speed: 2.3ms preprocess, 1875.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1880.0ms
# Speed: 2.2ms preprocess, 1880.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 24 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1870.0ms
# Speed: 2.4ms preprocess, 1870.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 9 Motorcycles, 4 Trucks, 1886.0ms
# Speed: 2.5ms preprocess, 1886.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 24 Cars, 11 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1883.2ms
# Speed: 2.7ms preprocess, 1883.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 25 Cars, 8 Motorcycles, 5 Trucks, 2293.3ms
# Speed: 2.1ms preprocess, 2293.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 24 Cars, 9 Motorcycles, 7 Trucks, 1876.9ms
# Speed: 2.1ms preprocess, 1876.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 25 Cars, 10 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1934.2ms
# Speed: 2.5ms preprocess, 1934.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 24 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1873.0ms
# Speed: 2.1ms preprocess, 1873.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 23 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1879.8ms
# Speed: 2.3ms preprocess, 1879.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 25 Cars, 12 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1954.7ms
# Speed: 2.2ms preprocess, 1954.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 24 Cars, 11 Motorcycles, 1 Tractor-trolley, 5 Trucks, 2235.2ms
# Speed: 2.2ms preprocess, 2235.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 26 Cars, 11 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1873.6ms
# Speed: 3.4ms preprocess, 1873.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 Cars, 11 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1892.9ms
# Speed: 2.2ms preprocess, 1892.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 Cars, 10 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1882.3ms
# Speed: 2.5ms preprocess, 1882.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 Cars, 11 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1886.2ms
# Speed: 2.0ms preprocess, 1886.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 Cars, 11 Motorcycles, 1 Tractor-trolley, 8 Trucks, 2012.7ms
# Speed: 2.0ms preprocess, 2012.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 Cars, 11 Motorcycles, 1 Tractor-trolley, 7 Trucks, 2186.7ms
# Speed: 2.1ms preprocess, 2186.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 Cars, 8 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1896.2ms
# Speed: 2.4ms preprocess, 1896.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1861.2ms
# Speed: 4.5ms preprocess, 1861.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1898.9ms
# Speed: 2.1ms preprocess, 1898.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 24 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1882.8ms
# Speed: 2.2ms preprocess, 1882.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 23 Cars, 8 Motorcycles, 1 Tractor-trolley, 7 Trucks, 2094.6ms
# Speed: 2.2ms preprocess, 2094.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 Cars, 10 Motorcycles, 1 Tractor-trolley, 5 Trucks, 2096.0ms
# Speed: 2.1ms preprocess, 2096.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 Cars, 8 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1877.0ms
# Speed: 2.3ms preprocess, 1877.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 25 Cars, 7 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1888.9ms
# Speed: 2.6ms preprocess, 1888.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 24 Cars, 7 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1890.4ms
# Speed: 2.1ms preprocess, 1890.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 23 Cars, 7 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1861.2ms
# Speed: 2.4ms preprocess, 1861.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 Cars, 7 Motorcycles, 1 Tractor-trolley, 9 Trucks, 2160.0ms
# Speed: 2.2ms preprocess, 2160.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 Cars, 10 Motorcycles, 1 Tractor-trolley, 10 Trucks, 1991.7ms
# Speed: 2.1ms preprocess, 1991.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 Cars, 10 Motorcycles, 1 Tractor-trolley, 9 Trucks, 1877.5ms
# Speed: 2.3ms preprocess, 1877.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 Cars, 9 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1860.4ms
# Speed: 2.3ms preprocess, 1860.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 10 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1879.3ms
# Speed: 2.6ms preprocess, 1879.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 Cars, 8 Motorcycles, 9 Trucks, 1857.8ms
# Speed: 3.1ms preprocess, 1857.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 10 Motorcycles, 1 Tractor-trolley, 9 Trucks, 2287.2ms
# Speed: 2.1ms preprocess, 2287.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 9 Motorcycles, 1 Tractor-trolley, 9 Trucks, 2425.0ms
# Speed: 1.9ms preprocess, 2425.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 9 Motorcycles, 1 Tractor-trolley, 9 Trucks, 1928.9ms
# Speed: 2.1ms preprocess, 1928.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 11 Motorcycles, 1 Tractor-trolley, 9 Trucks, 1886.3ms
# Speed: 2.3ms preprocess, 1886.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 11 Motorcycles, 1 Tractor-trolley, 10 Trucks, 1868.7ms
# Speed: 2.0ms preprocess, 1868.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 10 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1882.3ms
# Speed: 2.1ms preprocess, 1882.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 10 Motorcycles, 1 Tractor-trolley, 8 Trucks, 2321.4ms
# Speed: 2.4ms preprocess, 2321.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 9 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1893.7ms
# Speed: 6.3ms preprocess, 1893.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 10 Motorcycles, 1 Tractor-trolley, 10 Trucks, 1896.4ms
# Speed: 2.3ms preprocess, 1896.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 9 Motorcycles, 1 Tractor-trolley, 10 Trucks, 1861.2ms
# Speed: 2.7ms preprocess, 1861.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 9 Motorcycles, 1 Tractor-trolley, 9 Trucks, 1870.4ms
# Speed: 2.3ms preprocess, 1870.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 8 Motorcycles, 1 Tractor-trolley, 10 Trucks, 1865.3ms
# Speed: 2.5ms preprocess, 1865.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 22 Cars, 8 Motorcycles, 1 Tractor-trolley, 10 Trucks, 2290.7ms
# Speed: 2.5ms preprocess, 2290.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 Cars, 7 Motorcycles, 1 Tractor-trolley, 11 Trucks, 1898.4ms
# Speed: 2.1ms preprocess, 1898.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 Cars, 8 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1883.0ms
# Speed: 2.7ms preprocess, 1883.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 6 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1847.6ms
# Speed: 2.4ms preprocess, 1847.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 9 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1906.1ms
# Speed: 2.0ms preprocess, 1906.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 7 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1917.5ms
# Speed: 3.3ms preprocess, 1917.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 Cars, 8 Motorcycles, 1 Tractor-trolley, 8 Trucks, 2216.2ms
# Speed: 2.0ms preprocess, 2216.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 Cars, 9 Motorcycles, 6 Trucks, 1897.5ms
# Speed: 1.9ms preprocess, 1897.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 Cars, 9 Motorcycles, 7 Trucks, 1882.4ms
# Speed: 2.4ms preprocess, 1882.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 Cars, 11 Motorcycles, 7 Trucks, 1893.3ms
# Speed: 2.6ms preprocess, 1893.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 Cars, 11 Motorcycles, 5 Trucks, 1886.0ms
# Speed: 2.1ms preprocess, 1886.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 Cars, 11 Motorcycles, 6 Trucks, 2014.1ms
# Speed: 2.3ms preprocess, 2014.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 Cars, 10 Motorcycles, 6 Trucks, 2122.0ms
# Speed: 4.9ms preprocess, 2122.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 10 Motorcycles, 7 Trucks, 1916.3ms
# Speed: 2.1ms preprocess, 1916.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 9 Motorcycles, 1 Tractor-trolley, 8 Trucks, 1881.2ms
# Speed: 3.3ms preprocess, 1881.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 10 Motorcycles, 9 Trucks, 1862.5ms
# Speed: 3.1ms preprocess, 1862.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 Cars, 9 Motorcycles, 7 Trucks, 1895.2ms
# Speed: 2.6ms preprocess, 1895.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 21 Cars, 11 Motorcycles, 1 Tractor-trolley, 8 Trucks, 2056.6ms
# Speed: 2.4ms preprocess, 2056.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 23 Cars, 7 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1992.7ms
# Speed: 4.9ms preprocess, 1992.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 21 Cars, 8 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1900.0ms
# Speed: 5.1ms preprocess, 1900.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 21 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1911.1ms
# Speed: 2.6ms preprocess, 1911.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 Cars, 8 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1857.7ms
# Speed: 2.1ms preprocess, 1857.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1893.6ms
# Speed: 2.0ms preprocess, 1893.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 11 Motorcycles, 8 Trucks, 2233.5ms
# Speed: 2.9ms preprocess, 2233.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 10 Motorcycles, 8 Trucks, 1861.3ms
# Speed: 2.4ms preprocess, 1861.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 10 Motorcycles, 9 Trucks, 1891.0ms
# Speed: 2.2ms preprocess, 1891.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 19 Cars, 11 Motorcycles, 9 Trucks, 1857.3ms
# Speed: 2.4ms preprocess, 1857.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 21 Cars, 10 Motorcycles, 7 Trucks, 1880.7ms
# Speed: 2.4ms preprocess, 1880.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 21 Cars, 9 Motorcycles, 2 Tractor-trolleys, 6 Trucks, 1896.2ms
# Speed: 2.3ms preprocess, 1896.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 23 Cars, 8 Motorcycles, 1 Tractor-trolley, 5 Trucks, 2151.1ms
# Speed: 2.2ms preprocess, 2151.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1882.9ms
# Speed: 2.5ms preprocess, 1882.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 21 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1871.8ms
# Speed: 2.8ms preprocess, 1871.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 22 Cars, 7 Motorcycles, 6 Trucks, 1871.1ms
# Speed: 2.1ms preprocess, 1871.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 7 Motorcycles, 6 Trucks, 1856.8ms
# Speed: 3.2ms preprocess, 1856.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 Cars, 8 Motorcycles, 6 Trucks, 2090.6ms
# Speed: 2.1ms preprocess, 2090.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 19 Cars, 8 Motorcycles, 7 Trucks, 2001.1ms
# Speed: 2.1ms preprocess, 2001.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 19 Cars, 10 Motorcycles, 8 Trucks, 1867.9ms
# Speed: 2.3ms preprocess, 1867.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 18 Cars, 10 Motorcycles, 7 Trucks, 1857.9ms
# Speed: 2.6ms preprocess, 1857.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 12 Motorcycles, 6 Trucks, 1891.4ms
# Speed: 2.1ms preprocess, 1891.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 9 Motorcycles, 8 Trucks, 1910.9ms
# Speed: 5.2ms preprocess, 1910.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 11 Motorcycles, 6 Trucks, 2205.7ms
# Speed: 2.4ms preprocess, 2205.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 21 Cars, 9 Motorcycles, 6 Trucks, 1897.0ms
# Speed: 6.4ms preprocess, 1897.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 9 Motorcycles, 5 Trucks, 1886.1ms
# Speed: 2.4ms preprocess, 1886.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 7 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1867.2ms
# Speed: 2.0ms preprocess, 1867.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 21 Cars, 7 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1895.0ms
# Speed: 2.1ms preprocess, 1895.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 21 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1882.3ms
# Speed: 2.3ms preprocess, 1882.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 7 Motorcycles, 1 Tractor-trolley, 5 Trucks, 2198.5ms
# Speed: 2.6ms preprocess, 2198.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 22 Cars, 8 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1895.7ms
# Speed: 2.3ms preprocess, 1895.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 10 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1866.3ms
# Speed: 3.7ms preprocess, 1866.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 10 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1889.7ms
# Speed: 2.3ms preprocess, 1889.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1883.4ms
# Speed: 2.2ms preprocess, 1883.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 19 Cars, 10 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2041.1ms
# Speed: 3.7ms preprocess, 2041.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 19 Cars, 10 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2021.1ms
# Speed: 3.8ms preprocess, 2021.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 10 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1867.7ms
# Speed: 3.0ms preprocess, 1867.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 22 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1849.4ms
# Speed: 2.0ms preprocess, 1849.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 10 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1888.7ms
# Speed: 3.2ms preprocess, 1888.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 20 Cars, 8 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1874.9ms
# Speed: 2.1ms preprocess, 1874.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 10 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2722.9ms
# Speed: 2.1ms preprocess, 2722.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 2626.1ms
# Speed: 4.0ms preprocess, 2626.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 13 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2030.1ms
# Speed: 6.2ms preprocess, 2030.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 10 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1889.8ms
# Speed: 2.0ms preprocess, 1889.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1862.3ms
# Speed: 2.2ms preprocess, 1862.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 Cars, 10 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1863.7ms
# Speed: 2.5ms preprocess, 1863.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 Cars, 11 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2220.6ms
# Speed: 2.2ms preprocess, 2220.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 Cars, 12 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1889.2ms
# Speed: 3.3ms preprocess, 1889.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 11 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1883.7ms
# Speed: 2.0ms preprocess, 1883.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1859.9ms
# Speed: 2.2ms preprocess, 1859.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 7 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1893.4ms
# Speed: 2.2ms preprocess, 1893.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 Cars, 7 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1985.8ms
# Speed: 2.2ms preprocess, 1985.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 8 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2174.6ms
# Speed: 2.6ms preprocess, 2174.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 8 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1870.4ms
# Speed: 2.4ms preprocess, 1870.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 8 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1865.8ms
# Speed: 2.3ms preprocess, 1865.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 8 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1901.0ms
# Speed: 2.2ms preprocess, 1901.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 9 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1876.0ms
# Speed: 2.5ms preprocess, 1876.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 2162.4ms
# Speed: 2.3ms preprocess, 2162.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1931.3ms
# Speed: 2.0ms preprocess, 1931.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 19 Cars, 10 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1851.3ms
# Speed: 2.0ms preprocess, 1851.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 9 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1885.1ms
# Speed: 2.1ms preprocess, 1885.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 21 Cars, 11 Motorcycles, 1 Tractor-trolley, 3 Trucks, 1860.0ms
# Speed: 2.1ms preprocess, 1860.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 Cars, 10 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1901.0ms
# Speed: 2.5ms preprocess, 1901.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 2207.1ms
# Speed: 2.6ms preprocess, 2207.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 Cars, 8 Motorcycles, 1 Tractor-trolley, 4 Trucks, 1911.2ms
# Speed: 2.1ms preprocess, 1911.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 Cars, 7 Motorcycles, 1 Tractor-trolley, 7 Trucks, 1898.7ms
# Speed: 2.2ms preprocess, 1898.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Auto-rickshaw, 19 Cars, 6 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1878.0ms
# Speed: 2.0ms preprocess, 1878.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 7 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1869.9ms
# Speed: 2.1ms preprocess, 1869.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 Cars, 9 Motorcycles, 1 Tractor-trolley, 5 Trucks, 1943.4ms
# Speed: 2.3ms preprocess, 1943.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 2099.3ms
# Speed: 5.0ms preprocess, 2099.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1883.8ms
# Speed: 2.1ms preprocess, 1883.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 Cars, 8 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1877.0ms
# Speed: 2.0ms preprocess, 1877.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 Cars, 9 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1864.6ms
# Speed: 2.6ms preprocess, 1864.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 Cars, 8 Motorcycles, 1 Tractor-trolley, 6 Trucks, 1897.9ms
# Speed: 2.4ms preprocess, 1897.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Video processing completed.

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
